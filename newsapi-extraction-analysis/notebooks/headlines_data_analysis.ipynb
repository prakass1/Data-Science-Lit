# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("E:/input/headlines.csv",sep="|")

# %%
data.head(5)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>author</th>
#       <th>title</th>
#       <th>description</th>
#       <th>url</th>
#       <th>publishedAt</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Masslive.com</td>
#       <td>Christopher Smith | csmith@masslive.com</td>
#       <td>Romell Jordan, Boston Red Sox catcher Blake Sw...</td>
#       <td>Boston Red Sox catcher Blake Swihart's parents...</td>
#       <td>https://www.masslive.com/redsox/2019/02/romell...</td>
#       <td>2019-02-27T17:43:00Z</td>
#       <td>sports</td>
#     </tr>
#     <tr>
#       <th>1</th>
# ...
